-- %% [markdown]
-- # [ETicaretDemeDb]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ETicaretDemeDb]    Script Date: 21.11.2023 13:11:34 ******/
CREATE DATABASE [ETicaretDemeDb]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ETicaretDemeDb', FILENAME = N'G:\sql\MSSQL16.SQLEXPRESS\MSSQL\DATA\ETicaretDemeDb.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ETicaretDemeDb_log', FILENAME = N'G:\sql\MSSQL16.SQLEXPRESS\MSSQL\DATA\ETicaretDemeDb_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ETicaretDemeDb] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ETicaretDemeDb].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ETicaretDemeDb] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET ARITHABORT OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ETicaretDemeDb] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ETicaretDemeDb] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ETicaretDemeDb] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ETicaretDemeDb] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [ETicaretDemeDb] SET  MULTI_USER 
GO
ALTER DATABASE [ETicaretDemeDb] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ETicaretDemeDb] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ETicaretDemeDb] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ETicaretDemeDb] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ETicaretDemeDb] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ETicaretDemeDb] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [ETicaretDemeDb] SET QUERY_STORE = ON
GO
ALTER DATABASE [ETicaretDemeDb] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Sepetim]

-- %%
USE [ETicaretDemeDb]
GO

-- %%
/****** Object:  Table [dbo].[Sepetim]    Script Date: 21.11.2023 13:11:34 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sepetim](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UrunAdi] [varchar](max) NOT NULL,
	[Adet] [int] NOT NULL,
	[BirimFiyati] [money] NOT NULL,
	[Toplam] [money] NOT NULL,
 CONSTRAINT [PK_Sepet] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Urunler]

-- %%
/****** Object:  Table [dbo].[Urunler]    Script Date: 21.11.2023 13:11:34 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Urunler](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UrunAdi] [varchar](max) NOT NULL,
	[BirimFiyati] [money] NOT NULL,
	[Resim] [varchar](max) NOT NULL,
 CONSTRAINT [PK_Urunler] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [ETicaretDemeDb]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ETicaretDemeDb] SET  READ_WRITE 
GO
